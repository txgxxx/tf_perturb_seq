# %%
import synapseclient 
import synapseutils 

syn = synapseclient.Synapse() 
auth_id = "eyJ0eXAiOiJKV1QiLCJraWQiOiJXN05OOldMSlQ6SjVSSzpMN1RMOlQ3TDc6M1ZYNjpKRU9VOjY0NFI6VTNJWDo1S1oyOjdaQ0s6RlBUSCIsImFsZyI6IlJTMjU2In0..orUvOq26ZI_sE8iOCHuWcpNID9na3QyKbm6UQxxEsezY8qI_IYSvzdA33IhbI_E2cPhR8PQA5APRiC3JELwlQ4txwCG314KFeehBKnilrSy1zl7zkqHu1niS5l-5q2TZQiQLlqVzApl1V7d3gZB_yc-zjoDzV2F5EcnvCFXb7ObGw9nzsNdzFRoe4k9iXasOKE5_d7v9EDhEQOhHb7GcSv_n1Zp6D218AnIJPnqefI32OafHoBOuwiQskcpfiLHcXU8zk4v_7FzYhRt0IORG0ZPc7cJpKG8r8B86tKbU-nSVSzO-ygBG73AxYE6Hs-93j5V_qxjMvvaVdH3QEBwhww"
syn.login(authToken=auth_id) 
files = synapseutils.syncFromSynapse(syn, 'syn74847641')
# Out:
# Welcome, tsgaaaaw!
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn74847641:wtc11_cardio_cardiomyocyte]: Syncing Folder from Synapse.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn74930246:igvf3_wtc11_cardio_cardiomyocyte_scE2G_multiome_powerlaw_v3.e2g.tsv.gz]: Found existing file at /home2/s440862/.synapseCache/755/173000755/igvf3_wtc11_cardio_cardiomyocyte_scE2G_multiome_powerlaw_v3.e2g.tsv.gz, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn74930270:igvf3_wtc11_cardio_cardiomyocyte_scE2G_multiome_powerlaw_v3_threshold0.177.e2g.tsv.gz]: Found existing file at /home2/s440862/.synapseCache/802/173000802/igvf3_wtc11_cardio_cardiomyocyte_scE2G_multiome_powerlaw_v3_threshold0.177.e2g.tsv.gz, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:01<?, ?B/s]
# [syn74930317:igvf3_wtc11_cardio_cardiomyocyte_scE2G_scATAC_powerlaw_v3.e2g.tsv.gz]: Found existing file at /home2/s440862/.synapseCache/890/173000890/igvf3_wtc11_cardio_cardiomyocyte_scE2G_scATAC_powerlaw_v3.e2g.tsv.gz, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:01<?, ?B/s]
# [syn74930264:igvf3_wtc11_cardio_cardiomyocyte_scE2G_scATAC_powerlaw_v3_threshold0.174.e2g.tsv.gz]: Found existing file at /home2/s440862/.synapseCache/786/173000786/igvf3_wtc11_cardio_cardiomyocyte_scE2G_scATAC_powerlaw_v3_threshold0.174.e2g.tsv.gz, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:01<?, ?B/s]

# %%
import pandas as pd
from pathlib import Path

sce2g_path = Path(
    "/home2/s440862/.synapseCache/802/173000802/"
    "igvf3_wtc11_cardio_cardiomyocyte_scE2G_multiome_powerlaw_v3_threshold0.177.e2g.tsv.gz"
)

info = pd.read_csv(sce2g_path, sep="\t", comment="#")

# %%
info
# Out:
#       ElementChr  ElementStart  ElementEnd               ElementName  \
# 0           chr1        778181      778964        chr1:778181-778964
# 1           chr1        826516      827016        chr1:826516-827016
# 2           chr1        826516      827016        chr1:826516-827016
# 3           chr1        827272      827840        chr1:827272-827840
# 4           chr1        827272      827840        chr1:827272-827840
# ...          ...           ...         ...                       ...
# 55638       chrX     155864329   155864829  chrX:155864329-155864829
# 55639       chrX     155868101   155868601  chrX:155868101-155868601
# 55640       chrX     155868720   155869220  chrX:155868720-155869220
# 55641       chrX     155881029   155881534  chrX:155881029-155881534
# 55642       chrX     155966818   155967318  chrX:155966818-155967318
#
#       ElementClass GeneSymbol    GeneEnsemblID    GeneTSS  \
# 0       intergenic  LINC01128  ENSG00000228794     827590
# 1            genic  LINC00115  ENSG00000225880     827522
# 2            genic  LINC01128  ENSG00000228794     827590
# 3         promoter  LINC00115  ENSG00000225880     827522
# 4         promoter  LINC01128  ENSG00000228794     827590
# ...            ...        ...              ...        ...
# 55638   intergenic      SPRY3  ENSG00000168939  155767734
# 55639   intergenic      SPRY3  ENSG00000168939  155767734
# 55640   intergenic      SPRY3  ENSG00000168939  155767734
# 55641     promoter      VAMP7  ENSG00000124333  155881279
# 55642   intergenic      VAMP7  ENSG00000124333  155881279
#
#                SampleSummaryShort     Score  Score.ignoreTPM  isSelfPromoter
# 0      wtc11_cardio_cardiomyocyte  0.179209         0.179209           False
# 1      wtc11_cardio_cardiomyocyte  0.264953         0.264953           False
# 2      wtc11_cardio_cardiomyocyte  0.286776         0.286776           False
# 3      wtc11_cardio_cardiomyocyte  0.977320         0.977320            True
# 4      wtc11_cardio_cardiomyocyte  0.975716         0.975716            True
# ...                           ...       ...              ...             ...
# 55638  wtc11_cardio_cardiomyocyte  0.186781         0.186781           False
# 55639  wtc11_cardio_cardiomyocyte  0.191703         0.191703           False
# 55640  wtc11_cardio_cardiomyocyte  0.198490         0.198490           False
# 55641  wtc11_cardio_cardiomyocyte  0.969964         0.969964            True
# 55642  wtc11_cardio_cardiomyocyte  0.245525         0.245525           False
#
# [55643 rows x 12 columns]
